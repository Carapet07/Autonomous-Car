# %%
# Data Manipulation
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split

# Model Building
import tensorflow as tf
from tensorflow import keras
from ultralytics import YOLO

import os

# %%
# install the dataset and unzip it into the 'Datasets/TrafficSignsSet' folder 
# !kaggle datasets download -d pkdarabi/cardetection
# !unzip cardetection.zip -d '../Datasets/TrafficSignsSet'
# !rm -r cardetection.zip
