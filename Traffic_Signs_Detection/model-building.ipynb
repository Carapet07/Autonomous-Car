# %%
from ultralytics import YOLO
import cv2

# %%
# Use a pretrained YOLOv8 model
model = YOLO('Traffic_Signs_Detection/yolov8n.pt')

image = "../Datasets/TrafficSignsSet/car/train/images/00000_00000_00000_png.rf.55d47572c5980af0892b0c2ada6dae77.jpg"

result_predict = model.predict(source=image, imgsz=416, epochs=30)

plot = result_predict[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.8/lib/python3.11/pathlib.py:1116, in Path.mkdir(self, mode, parents, exist_ok)
#    1115 try:
# -> 1116     os.mkdir(self, mode)
#    1117 except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Traffic_Signs_Detection'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Use a pretrained YOLOv8 model
# ----> 2 model = YOLO('Traffic_Signs_Detection/yolov8n.pt')
#       4 image = "../Datasets/TrafficSignsSet/car/train/images/00000_00000_00000_png.rf.55d47572c5980af0892b0c2ada6dae77.jpg"
#       6 result_predict = model.predict(source=image, imgsz=416, epochs=30)
#
# ...
